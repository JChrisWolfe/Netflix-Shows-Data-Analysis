# %% [markdown]
# # Netflix Data Analytics

# %% [markdown]
# This dataset is downloadable on [Kaggle](https://www.kaggle.com/shivamb/netflix-shows). It has information on TV shows and Movies. The dataset used is Version 5 which was released on 9/27/2021.

# %% [markdown]
# ## Importing the Dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Doing this project in my Google Drive Account so I need to import drive from Google Colab then mount my Google Drive to access the Dataset. Skip this if this file is downloaded on a computer and just change the file path of `pd.read_csv()` of the code below.

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Now to read the CSV file using Python's Pandas. Change file path of the `pd.read_csv` method as needed.

# %%
df_netflix = pd.read_csv("/content/drive/MyDrive/Documents/Data Analysis Projects/Netflix Shows Data Analysis/netflix_titles.csv")

# %%
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Basic information on the Dataset

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Numbers of Rows and Columns?
df_netflix.shape 
# 8807 rows, 12 columns
# Out:
# (8807, 12)

# %%
# Total number of values(elements) in the dataset.
df_netflix.size
# Out:
# 105684

# %%
# List of column names
df_netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Data-type of each column
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Viewing the Range of Index, Number of Columns, Data-type of each column, 
# and Memory Size of the DataFrame all at once.
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## Removing any duplicate entries, if any.

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix.shape
# Out:
# (8807, 12)

# %%
# Checking rows that are duplicated data.
df_netflix[df_netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# No duplicates, but if there were their's a nice convenient method!
# `drop_duplicate()` method in Pandas module, would need `inplace = True` in the param to impletement
# permanent changes.

# %%
# df_netflix.drop_duplicates(inplace = True)

# %%
df_netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Checking for any null values in the Dataset.

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Show generally where null values are present.
df_netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# Count up total number of null values.
df_netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Use `seaborn`'s Heatmap to show grapic display of the amount of null values present.

# %% [markdown]
# <p>
# <blockquote cite="https://www.educba.com/seaborn-heatmap/">
# A Heat map is a two-dimensional visualization method that shows the variation in the magnitude of a particular phenomenon in terms of different colors represented. The heat map is a data visualization technique that shows the shape and direction of different heat values at different temperature levels for a set of data points.
#
# ...
# A heat map is a data visualization technique that can give you a sense of whether the network or a feature has changed over time. For example, heat maps can illustrate the relationship between a number of different attributes or a data set and a characteristic such as the degrees of freedom (or number of degrees of freedom), accuracy, and so on.
# </blockquote>
#
# More information from [Educba](https://www.educba.com/seaborn-heatmap/)
# </p>
# <p>
# From <a href="https://www.geeksforgeeks.org/seaborn-heatmap-a-comprehensive-guide/">GeeksforGeeks</a>:
# <blockquotes cite="https://www.geeksforgeeks.org/seaborn-heatmap-a-comprehensive-guide/">
#
# Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.
# </blockquotes>
# </p>

# %%
import seaborn as sns

# %%
sns.heatmap(df_netflix.isnull())

# %% [markdown]
# ## Question 1: Who is the show director of "The Witcher", what is it's Show ID?

# %%
df_netflix[df_netflix['title'].isin(['The Witcher'])]
# Out:
#      show_id     type        title director  \
# 3117   s3118  TV Show  The Witcher      NaN
#
#                                                    cast  \
# 3117  Henry Cavill, Anya Chalotra, Freya Allan, Jodh...
#
#                     country         date_added  release_year rating  duration  \
# 3117  United States, Poland  December 20, 2019          2019  TV-MA  1 Season
#
#                                               listed_in  \
# 3117  International TV Shows, TV Action & Adventure,...
#
#                                             description
# 3117  Geralt of Rivia, a mutated monster-hunter for ...

# %%
df_netflix[df_netflix['title'].str.contains('The Witcher')]
# Out:
#      show_id     type                                    title      director  \
# 240     s241    Movie       The Witcher: Nightmare of the Wolf  Han Kwang Il
# 2058   s2059  TV Show  The Witcher: A Look Inside the Episodes           NaN
# 2095   s2096    Movie                       Making The Witcher  Nathan Wiley
# 3117   s3118  TV Show                              The Witcher           NaN
#
#                                                    cast  \
# 240   Theo James, Mary McDonnell, Lara Pulver, Graha...
# 2058  Henry Cavill, Anya Chalotra, Freya Allan, Laur...
# 2095  Henry Cavill, Anya Chalotra, Freya Allan, Eamo...
# 3117  Henry Cavill, Anya Chalotra, Freya Allan, Jodh...
#
#                     country         date_added  release_year rating  duration  \
# 240                     NaN    August 23, 2021          2021  TV-MA    84 min
# 2058                    NaN  September 2, 2020          2020  TV-MA  1 Season
# ...

# %% [markdown]
# ## Question 2: In which year was the highest number of the TV Shows & Movies that were released ? Show with a Bar Graph.

# %%
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_netflix["Date_Numerical"] = pd.to_datetime(df_netflix["date_added"])

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix["Date_Numerical"].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_Numerical, dtype: int64

# %%
df_netflix["Date_Numerical"].dt.year.value_counts().plot(kind="bar")

# %% [markdown]
# ## Question 3: How many Movies & TV Shows are in the dataset ? Show with a Bar Graph.

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix.groupby("type").type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(df_netflix["type"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Question 4: What are all the movies released in the year 2000?

# %%
df_netflix.head(7)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_netflix["Date_Numerical"].dt.year
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: Date_Numerical, Length: 8807, dtype: float64

# %%
df_netflix["Year"] = df_netflix["Date_Numerical"].dt.year

# %%
df_netflix.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
# ...

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['Year'] == 2000)] # No movies released in the year 2000 on Netflix.
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_Numerical, Year]
# Index: []

# %%
# Trying year 2016 as a test to see if the code in the block above is working as intended.
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['Year'] == 2016)] # It works as intended.
# Out:
#      show_id   type                                              title  \
# 5652   s5653  Movie                                            Mr. Pig
# 5656   s5657  Movie                                               7:19
# 5657   s5658  Movie          Garfunkel and Oates: Trying to be Special
# 5659   s5660  Movie  A Christmas Special: Miraculous: Tales of Lady...
# 5660   s5661  Movie  Gabriel lglesias: I’m Sorry For What I Said Wh...
# ...      ...    ...                                                ...
# 8781   s8782  Movie                            Yo-Kai Watch: The Movie
# 8782   s8783  Movie                                        Yoga Hosers
# 8788   s8789  Movie                                       You Carry Me
# 8792   s8793  Movie                                        Young Tiger
# 8801   s8802  Movie                                            Zinzana
#
#                           director  \
# 5652                    Diego Luna
# 5656             Jorge Michel Grau
# ...

# %% [markdown]
# There are no movies on Netflix released in the year 2000.

# %% [markdown]
# ## Question 5: Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df_netflix['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ## Question 6: Show all the Records, where "Category is Movie and Type is Comedies"

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['listed_in'].str.contains('Comedy') | df_netflix['listed_in'].str.contains('Comedies'))]
# Out:
#      show_id   type                             title  \
# 9        s10  Movie                      The Starling
# 13       s14  Movie  Confessions of an Invisible Girl
# 22       s23  Movie                   Avvai Shanmughi
# 24       s25  Movie                             Jeans
# 26       s27  Movie                    Minsara Kanavu
# ...      ...    ...                               ...
# 8791   s8792  Movie                       Young Adult
# 8793   s8794  Movie              Yours, Mine and Ours
# 8798   s8799  Movie                          Zed Plus
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
#
#                      director  \
# 9              Theodore Melfi
# 13              Bruno Garotti
# 22             K.S. Ravikumar
# 24                 S. Shankar
# 26                Rajiv Menon
# ...                       ...
# 8791            Jason Reitman
# 8793             Raja Gosnell
# 8798  Chandra Prakash Dwivedi
# ...

# %% [markdown]
# ## Question 7: What are the different Ratings defined by Netflix ?

# %%
df_netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
df_netflix["rating"].nunique()
# Out:
# 17

# %%
df_netflix["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Question 7.1: How many Movies got the 'TV-14' rating, in the United States?

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['rating'] == "TV-14")]
# Out:
#      show_id   type                                              title  \
# 18       s19  Movie                                          Intrusion
# 24       s25  Movie                                              Jeans
# 30       s31  Movie                                    Ankahi Kahaniya
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...    ...                                                ...
# 8772   s8773  Movie                              Yamla Pagla Deewana 2
# 8774   s8775  Movie                                          يوم الدين
# 8794   s8795  Movie                                             اشتباك
# 8799   s8800  Movie                                              Zenda
# 8806   s8807  Movie                                             Zubaan
#
#                                                director  \
# 18                                           Adam Salky
# ...

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['rating'] == "TV-14")].shape
# Out:
# (1427, 14)

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['rating'] == "TV-14") & (df_netflix["country"] == "United States")]
# Out:
#      show_id   type                             title             director  \
# 378     s379  Movie                   Fantastic Fungi   Louie Schwartzberg
# 800     s801  Movie                   Mosquita y Mari      Aurora Guerrero
# 870     s871  Movie        Amy Tan: Unintended Memoir        James Redford
# 948     s949  Movie                            Swiped  Ann Deborah Fishman
# 975     s976  Movie  Shadow and Bone - The Afterparty                  NaN
# ...      ...    ...                               ...                  ...
# 8657   s8658  Movie               Under an Arctic Sky        Chris Burkard
# 8673   s8674  Movie                        Vegas Baby       Amanda Micheli
# 8704   s8705  Movie                We Belong Together         Chris Stokes
# 8724   s8725  Movie                What Still Remains         Josh Mendoza
# 8752   s8753  Movie                          Wish Man          Theo Davies
#
# ...

# %%
df_netflix[(df_netflix['type'] == "Movie") & (df_netflix['rating'] == "TV-14") & (df_netflix["country"] == "United States")].shape
# Out:
# (213, 14)

# %% [markdown]
# ### Question 7.2: How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df_netflix.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description Date_Numerical    Year
# 0  As her father nears the end of his life, filmm...     2021-09-25  2021.0

# %%
df_netflix[(df_netflix['type'] == "TV Show") & (df_netflix['rating'] == "R") & (df_netflix["Year"] > 2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019          2015      R  1 Season  TV Shows
#
#                                             description Date_Numerical    Year
# 3893  Trapped at a stagecoach stop as a storm rages ...     2019-04-25  2019.0

# %%
df_netflix[(df_netflix['type'] == "TV Show") & (df_netflix['rating'] == "R") & (df_netflix["Year"] > 2018)].shape
# Out:
# (1, 14)

# %% [markdown]
# ## Question 8: What is the maximum duration of a Movie/Show on Netflix?

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix[["Minutes", "Unit"]] = df_netflix["duration"].str.split(" ", expand=True)

# %%
df_netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Date_Numerical    Year  \
# 0  As her father nears the end of his life, filmm...     2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t...     2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %%
df_netflix["Minutes"].fillna(0).unique()
# Out:
# array(['90', '2', '1', '91', '125', '9', '104', '127', '4', '67', '94',
#        '5', '161', '61', '166', '147', '103', '97', '106', '111', '3',
#        '110', '105', '96', '124', '116', '98', '23', '115', '122', '99',
#        '88', '100', '6', '102', '93', '95', '85', '83', '113', '13',
#        '182', '48', '145', '87', '92', '80', '117', '128', '119', '143',
#        '114', '118', '108', '63', '121', '142', '154', '120', '82', '109',
#        '101', '86', '229', '76', '89', '156', '112', '107', '129', '135',
#        '136', '165', '150', '133', '70', '84', '140', '78', '7', '64',
#        '59', '139', '69', '148', '189', '141', '130', '138', '81', '132',
#        '10', '123', '65', '68', '66', '62', '74', '131', '39', '46', '38',
#        '8', '17', '126', '155', '159', '137', '12', '273', '36', '34',
#        '77', '60', '49', '58', '72', '204', '212', '25', '73', '29', '47',
#        '32', '35', '71', '149', '33', '15', '54', '224', '162', '37',
# ...

# %%
np.int_(df_netflix["Minutes"].fillna(0).unique()).max()
# Out:
# 312

# %% [markdown]
# ## Question 9: Which individual country has the Highest No. of TV Shows?

# %%
df_netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Date_Numerical    Year  \
# 0  As her father nears the end of his life, filmm...     2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t...     2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %%
netflix_tvshows = df_netflix[df_netflix["type"] == "TV Show"]

# %%
netflix_tvshows.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
netflix_tvshows.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
netflix_tvshows.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64
